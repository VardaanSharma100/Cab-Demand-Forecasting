# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("../data/raw/ncr_rides_final_event_dataset_2024.csv")

# %%
df.head()
# Out:
#               datetime        Date      Time  year  month  day   weekday  \
# 0  2024-03-23 12:29:38  2024-03-23  12:29:38  2024      3   23  Saturday
# 1  2024-11-29 18:01:39  2024-11-29  18:01:39  2024     11   29    Friday
# 2  2024-08-23 08:56:10  2024-08-23  08:56:10  2024      8   23    Friday
# 3  2024-10-21 17:17:25  2024-10-21  17:17:25  2024     10   21    Monday
# 4  2024-09-16 22:08:00  2024-09-16  22:08:00  2024      9   16    Monday
#
#    hour   ride_date           Event  ... Avg CTAT Cancelled Rides by Customer  \
# 0    12  2024-03-23      Normal Day  ...      NaN                         NaN
# 1    18  2024-11-29  Wedding_Season  ...     14.0                         NaN
# 2     8  2024-08-23         Monsoon  ...     25.8                         NaN
# 3    17  2024-10-21      Normal Day  ...     28.5                         NaN
# 4    22  2024-09-16      Normal Day  ...     19.6                         NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160609 entries, 0 to 160608
# Data columns (total 29 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   datetime                           160609 non-null  object
#  1   Date                               160609 non-null  object
#  2   Time                               160609 non-null  object
#  3   year                               160609 non-null  int64
#  4   month                              160609 non-null  int64
#  5   day                                160609 non-null  int64
#  6   weekday                            160609 non-null  object
#  7   hour                               160609 non-null  int64
#  8   ride_date                          160609 non-null  object
#  9   Event                              160609 non-null  object
#  10  Booking ID                         160609 non-null  object
# ...

# %%
df.drop(['datetime','ride_date','Booking ID','Avg VTAT','Avg CTAT','Cancelled Rides by Customer','Reason for cancelling by Customer','Cancelled Rides by Driver','Driver Cancellation Reason','Incomplete Rides','Incomplete Rides Reason','Driver Ratings','Customer Rating','Payment Method'],inplace=True,axis=1)

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'year', 'month', 'day', 'weekday', 'hour', 'Event',
#        'Booking Status', 'Customer ID', 'Vehicle Type', 'Pickup Location',
#        'Drop Location', 'Ride Distance', 'Booking Value'],
#       dtype='object')

# %%
df.head()
# Out:
#          Date      Time  year  month  day   weekday  hour           Event  \
# 0  2024-03-23  12:29:38  2024      3   23  Saturday    12      Normal Day
# 1  2024-11-29  18:01:39  2024     11   29    Friday    18  Wedding_Season
# 2  2024-08-23  08:56:10  2024      8   23    Friday     8         Monsoon
# 3  2024-10-21  17:17:25  2024     10   21    Monday    17      Normal Day
# 4  2024-09-16  22:08:00  2024      9   16    Monday    22      Normal Day
#
#     Booking Status   Customer ID   Vehicle Type      Pickup Location  \
# 0  No Driver Found  "CID1982111"          eBike          Palam Vihar
# 1       Incomplete  "CID4604802"       Go Sedan        Shastri Nagar
# 2        Completed  "CID9202816"           Auto              Khandsa
# 3        Completed  "CID2610914"  Premier Sedan  Central Secretariat
# 4        Completed  "CID9933542"           Bike     Ghitorni Village
#
#        Drop Location  Ride Distance  Booking Value
# 0            Jhilmil            NaN            NaN
# ...

# %%
df.drop(['Customer ID'],inplace=True,axis=1)

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'year', 'month', 'day', 'weekday', 'hour', 'Event',
#        'Booking Status', 'Vehicle Type', 'Pickup Location', 'Drop Location',
#        'Ride Distance', 'Booking Value'],
#       dtype='object')

# %%
df.head()
# Out:
#          Date      Time  year  month  day   weekday  hour           Event  \
# 0  2024-03-23  12:29:38  2024      3   23  Saturday    12      Normal Day
# 1  2024-11-29  18:01:39  2024     11   29    Friday    18  Wedding_Season
# 2  2024-08-23  08:56:10  2024      8   23    Friday     8         Monsoon
# 3  2024-10-21  17:17:25  2024     10   21    Monday    17      Normal Day
# 4  2024-09-16  22:08:00  2024      9   16    Monday    22      Normal Day
#
#     Booking Status   Vehicle Type      Pickup Location      Drop Location  \
# 0  No Driver Found          eBike          Palam Vihar            Jhilmil
# 1       Incomplete       Go Sedan        Shastri Nagar  Gurgaon Sector 56
# 2        Completed           Auto              Khandsa      Malviya Nagar
# 3        Completed  Premier Sedan  Central Secretariat           Inderlok
# 4        Completed           Bike     Ghitorni Village        Khan Market
#
#    Ride Distance  Booking Value
# 0            NaN            NaN
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of               Date      Time  year  month  day    weekday  hour  \
# 0       2024-03-23  12:29:38  2024      3   23   Saturday    12
# 1       2024-11-29  18:01:39  2024     11   29     Friday    18
# 2       2024-08-23  08:56:10  2024      8   23     Friday     8
# 3       2024-10-21  17:17:25  2024     10   21     Monday    17
# 4       2024-09-16  22:08:00  2024      9   16     Monday    22
# ...            ...       ...   ...    ...  ...        ...   ...
# 160604  2024-11-24  15:55:09  2024     11   24     Sunday    15
# 160605  2024-09-18  10:55:15  2024      9   18  Wednesday    10
# 160606  2024-10-05  07:53:34  2024     10    5   Saturday     7
# 160607  2024-10-05  07:53:34  2024     10    5   Saturday     7
# 160608  2024-03-10  15:38:03  2024      3   10     Sunday    15
#
#                  Event   Booking Status   Vehicle Type  \
# 0           Normal Day  No Driver Found          eBike
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160609 entries, 0 to 160608
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Date             160609 non-null  object
#  1   Time             160609 non-null  object
#  2   year             160609 non-null  int64
#  3   month            160609 non-null  int64
#  4   day              160609 non-null  int64
#  5   weekday          160609 non-null  object
#  6   hour             160609 non-null  int64
#  7   Event            160609 non-null  object
#  8   Booking Status   160609 non-null  object
#  9   Vehicle Type     160609 non-null  object
#  10  Pickup Location  160609 non-null  object
#  11  Drop Location    160609 non-null  object
#  12  Ride Distance    109329 non-null  float64
#  13  Booking Value    109329 non-null  float64
# dtypes: float64(2), int64(4), object(8)
# memory usage: 17.2+ MB

# %%
np.set_printoptions(threshold=np.inf)
df['Booking Status'].unique()
# Out:
# Booking Status
# Completed                99666
# Cancelled by Driver      28819
# Cancelled by Customer    11254
# No Driver Found          11207
# Incomplete                9663
# Name: count, dtype: int64

# %%
df['Vehicle Type'].unique()
# Out:
# array(['eBike', 'Go Sedan', 'Auto', 'Premier Sedan', 'Bike', 'Go Mini',
#        'Uber XL'], dtype=object)

# %%
df['Booking Status'].value_counts()
# Out:
# Booking Status
# Completed                99666
# Cancelled by Driver      28819
# Cancelled by Customer    11254
# No Driver Found          11207
# Incomplete                9663
# Name: count, dtype: int64

# %%
df['Vehicle Type'].value_counts()
# Out:
# Vehicle Type
# Auto             40066
# Go Mini          31873
# Go Sedan         29042
# Bike             24108
# Premier Sedan    19453
# eBike            11285
# Uber XL           4782
# Name: count, dtype: int64

# %%
df['Booking Value'].count()
# Out:
# 109329

# %%
df_with_price=df[df['Booking Value'].notnull()]
df_with_price['Booking Status'].value_counts()
# Out:
# Booking Status
# Completed     99666
# Incomplete     9663
# Name: count, dtype: int64

# %%
df.dropna(subset=['Booking Value'],inplace=True)

# %%
df['Booking Value'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#               Date      Time  year  month  day    weekday  hour  \
# 1       2024-11-29  18:01:39  2024     11   29     Friday    18
# 2       2024-08-23  08:56:10  2024      8   23     Friday     8
# 3       2024-10-21  17:17:25  2024     10   21     Monday    17
# 4       2024-09-16  22:08:00  2024      9   16     Monday    22
# 5       2024-02-06  09:44:56  2024      2    6    Tuesday     9
# ...            ...       ...   ...    ...  ...        ...   ...
# 160604  2024-11-24  15:55:09  2024     11   24     Sunday    15
# 160605  2024-09-18  10:55:15  2024      9   18  Wednesday    10
# 160606  2024-10-05  07:53:34  2024     10    5   Saturday     7
# 160607  2024-10-05  07:53:34  2024     10    5   Saturday     7
# 160608  2024-03-10  15:38:03  2024      3   10     Sunday    15
#
#                  Event Booking Status   Vehicle Type         Pickup Location  \
# 1       Wedding_Season     Incomplete       Go Sedan           Shastri Nagar
# ...

# %%
df=df[df['Booking Status']=='Completed']

# %%
df['Booking Status'].value_counts()
# Out:
# Booking Status
# Completed    99666
# Name: count, dtype: int64

# %%
df['Booking Value'].value_counts().sum()
# Out:
# 99666

# %%
df.to_csv('temp.csv',index=False)
